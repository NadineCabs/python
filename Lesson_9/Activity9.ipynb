# %% [markdown]
# # LESSON 9

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats

# %%
X, y = make_blobs(n_samples=300, centers=3, cluster_std=1.0, random_state=42)
data = pd.DataFrame(X, columns=['Feature1', 'Feature2'])
data['TrueLabel'] = y
data.head()
# Out:
#    Feature1  Feature2  TrueLabel
# 0 -7.338988 -7.729954          2
# 1 -7.740041 -7.264665          2
# 2 -1.686653  7.793442          0
# 3  4.422198  3.071947          1
# 4 -8.917752 -7.888196          2

# %%
import os
os.environ['OMP_NUM_THREADS'] = '2'
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)
data['KMeansLabel'] = kmeans.predict(X)
# Out:
# C:\Users\Nadine Caballero\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
